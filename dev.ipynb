# %%
import nest_asyncio
nest_asyncio.apply()

import dotenv
import json

from contrast_tool import ContrastTool

# %%
dotenv.load_dotenv()

old_file = r"C:\Users\info\Desktop\harlus\ml\tools\contrast_tool\data\AMAT Q1 24 results.pdf"
new_file = r"C:\Users\info\Desktop\harlus\ml\tools\contrast_tool\data\AMAT Q3 24 results.pdf"

tool = ContrastTool()

print(json.dumps(tool.compare_documents_from_path(old_file, new_file), indent=2))
# Out:
# Extracting claims from old document: C:\Users\info\Desktop\harlus\ml\tools\contrast_tool\data\AMAT Q1 24 results.pdf
# Claim: Gross margin is expected to be 47%, up from 46.2% in the same quarter one year ago.
# Claim: Adjusted EPS is expected to be $2.01, up from $1.90 last year.
# Claim: AMAT expects to generate more than $2.5bn of revenue from gate-all-around nodes and potentially more than double that in 2025.
# Claim: AMAT expects revenue coming from HBM equipment to multiply by x6 this year, growing to more than $600mn.
# Claim: For their Q3 (ending July 31st), AMAT guided for sales of $6.65bn, plus minus $400mn.
#
# Analyzing claims against new document: C:\Users\info\Desktop\harlus\ml\tools\contrast_tool\data\AMAT Q3 24 results.pdf
# Started parsing the file under job_id 4e1ef96f-459b-42ae-b4ec-40e2b3b70617
#
# Verdict:
# {
#   "Gross margin is expected to be 47%, up from 46.2% in the same quarter one year ago.": {
#     "questions": [
# ...
