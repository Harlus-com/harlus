# %%
import sys
sys.path.append("/Users/ronald/Documents/code/harlus/server")

# %%
import harlus_doc_search
import harlus_chat
import harlus_contrast_tool

# %%
import datetime
import json
import pickle
import time
from fastapi import (
    FastAPI,
    Query,
    Response,
    WebSocket,
)
import os
import asyncio
import nest_asyncio
from fastapi.middleware.cors import CORSMiddleware
from fastapi.responses import FileResponse, JSONResponse, StreamingResponse
from openai import OpenAI
from platformdirs import user_data_dir
from pathlib import Path
from llama_index.core.agent.workflow import ReActAgent

from pydantic import BaseModel, ConfigDict, Field
from src.util import BoundingBoxConverter, snake_to_camel
from src.tool_library import ToolLibrary
from src.sync_workspace import get_workspace_sync_manager

# from src.stream_response import stream_generator_v2 # TODO: Delete this file
from src.file_store import FileStore, Workspace, File
from src.sync_queue import SyncQueue, SyncType
from src.stream_manager import StreamManager
from src.sync_status import SyncStatus
from src.chat_library import ChatLibrary
from harlus_contrast_tool import ContrastTool
from harlus_chat import ChatAgentGraph


app = FastAPI()
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=False,
    allow_methods=["*"],
    allow_headers=["*"],
)

asyncio.set_event_loop_policy(asyncio.DefaultEventLoopPolicy())


nest_asyncio.apply(asyncio)

DEV_APP_DATA_PATH = Path(user_data_dir("Electron")).joinpath("Harlus")

# On MacOs for development this will be something like
# /Users/danielglasgow/Library/Application Support/Electron
# TODO: Determine what this will be in production
# Probably something like /Users/danielglasgow/Library/Application Support/Harlus
# Also need to determine what this will be for Windows
# Ultimately this value is passed in by the Electron app in prod.
APP_DATA_PATH_STRING = os.environ.get("APP_DATA_PATH")
if (
    not APP_DATA_PATH_STRING
    or "Electron" in APP_DATA_PATH_STRING
    or "electron" in APP_DATA_PATH_STRING
):
    APP_DATA_PATH = DEV_APP_DATA_PATH
else:
    APP_DATA_PATH = Path(APP_DATA_PATH_STRING)

print("APP_DATA_PATH", APP_DATA_PATH)

file_store = FileStore(APP_DATA_PATH)

tool_library = ToolLibrary(file_store)
tool_library.load_tools()


# TODO: chat_library should call update_chat_tools when new tools
# are added to the tool_library to ensure chat has access to all tools 
# within the workspace. 
chat_library = ChatLibrary(file_store, tool_library)
chat_library.load() # initialize a chat for each workspace, load from disk to memory
# Out:
# APP_DATA_PATH /Users/ronald/Library/Application Support/Electron/Harlus
# Initializing FileStore with app_data_path /Users/ronald/Library/Application Support/Electron/Harlus
# Loaded tools for /Users/ronald/Library/Application Support/Electron/Harlus/AAPL/20241101_Q4_2024_AAPL_10_K_pdf/content.pdf: ['sentence_retriever_tool', 'doc_search', 'verdict_query_engine_tool', 'claim_query_engine_tool']
# Loaded chat_model for workspace AAPL
# [harlus_chat] adding tools
#  - adding doc search tool

# %%
workspace_id = list(file_store.get_workspaces().keys())[0]
chat = chat_library.get(workspace_id=workspace_id)

# %%
chat.start_new_thread()

# %%
async for chunk in chat.stream(user_message="What is the gross margin of Apple?"):
    print(chunk)
# Out:
# [harlus_chat] Streaming answer...
# data: {"text": ""}
# event: reading_message
#
#
#
# data: {"text": "I"}
# event: reading_message
#
#
#
# data: {"text": " will"}
# event: reading_message
#
#
#
# data: {"text": " read"}
# event: reading_message
#
#
#
# data: {"text": " the"}
# event: reading_message
#
#
#
# data: {"text": " "}
# event: reading_message
#
#
#
# data: {"text": "202"}
# event: reading_message
#
#
#
# data: {"text": "4"}
# event: reading_message
#
#
#
# data: {"text": " Annual"}
# event: reading_message
#
#
#
# data: {"text": " "}
# event: reading_message
#
#
#
# data: {"text": "10"}
# event: reading_message
#
#
#
# data: {"text": "-K"}
# event: reading_message
#
#
#
# data: {"text": " report"}
# event: reading_message
#
#
#
# data: {"text": " of"}
# event: reading_message
#
#
#
# data: {"text": " Apple"}
# event: reading_message
#
#
#
# data: {"text": " to"}
# event: reading_message
#
#
#
# data: {"text": " find"}
# event: reading_message
#
#
#
# data: {"text": " information"}
# event: reading_message
#
#
#
# data: {"text": " on"}
# event: reading_message
#
#
#
# data: {"text": " the"}
# event: reading_message
#
#
#
# data: {"text": " company's"}
# event: reading_message
#
#
#
# data: {"text": " gross"}
# event: reading_message
#
#
#
# data: {"text": " margin"}
# event: reading_message
#
#
#
# data: {"text": "."}
# event: reading_message
#
#
#
# data: {"text": " This"}
# event: reading_message
#
#
#
# data: {"text": " report"}
# event: reading_message
#
#
#
# data: {"text": " typically"}
# event: reading_message
#
#
#
# data: {"text": " includes"}
# event: reading_message
#
#
#
# data: {"text": " financial"}
# event: reading_message
#
#
#
# data: {"text": " performance"}
# event: reading_message
#
#
#
# data: {"text": " metrics"}
# event: reading_message
#
#
#
# data: {"text": ","}
# event: reading_message
#
#
#
# data: {"text": " including"}
# event: reading_message
#
#
#
# data: {"text": " gross"}
# event: reading_message
#
#
#
# data: {"text": " margin"}
# event: reading_message
#
#
#
# data: {"text": " figures"}
# event: reading_message
#
#
#
# data: {"text": "."}
# event: reading_message
#
#
#
# data: {"text": ""}
# event: reading_message
#
#
#
# data: {"text": ""}
# event: answer_message
#
#
#
# data: {"text": ""}
# event: answer_message
#
#
#
# data: {"text": ""}
# event: answer_message
#
#
#
# data: {"text": ""}
# event: answer_message
#
#
#
# data: {"text": ""}
# event: answer_message
#
#
#
# data: {"text": ""}
# event: answer_message
#
#
#
# data: {"text": ""}
# event: answer_message
#
#
#
# data: {"text": ""}
# event: answer_message
#
#
#
# [harlus_chat] processing tool calls
# - executing doc search tool call:  doc_search_20241101_Q4_2024_AAPL_10-K_pdf
# data: {"text": ""}
# event: answer_message
#
#
#
# data: {"text": "The"}
# event: answer_message
#
#
#
# data: {"text": " information"}
# event: answer_message
#
#
#
# data: {"text": " retrieved"}
# event: answer_message
#
#
#
# data: {"text": " from"}
# event: answer_message
#
#
#
# data: {"text": " the"}
# event: answer_message
#
#
#
# data: {"text": " "}
# event: answer_message
#
#
#
# data: {"text": "202"}
# event: answer_message
#
#
#
# data: {"text": "4"}
# event: answer_message
#
#
#
# data: {"text": " Annual"}
# event: answer_message
#
#
#
# data: {"text": " "}
# event: answer_message
#
#
#
# data: {"text": "10"}
# event: answer_message
#
#
#
# data: {"text": "-K"}
# event: answer_message
#
#
#
# data: {"text": " report"}
# event: answer_message
#
#
#
# data: {"text": " does"}
# event: answer_message
#
#
#
# data: {"text": " not"}
# event: answer_message
#
#
#
# data: {"text": " include"}
# event: answer_message
#
#
#
# data: {"text": " specific"}
# event: answer_message
#
#
#
# data: {"text": " details"}
# event: answer_message
#
#
#
# data: {"text": " about"}
# event: answer_message
#
#
#
# data: {"text": " Apple's"}
# event: answer_message
#
#
#
# data: {"text": " gross"}
# event: answer_message
#
#
#
# data: {"text": " margin"}
# event: answer_message
#
#
#
# data: {"text": "."}
# event: answer_message
#
#
#
# data: {"text": " It"}
# event: answer_message
#
#
#
# data: {"text": " primarily"}
# event: answer_message
#
#
#
# data: {"text": " focuses"}
# event: answer_message
#
#
#
# data: {"text": " on"}
# event: answer_message
#
#
#
# data: {"text": " the"}
# event: answer_message
#
#
#
# data: {"text": " company's"}
# event: answer_message
#
#
#
# data: {"text": " report"}
# event: answer_message
#
#
#
# data: {"text": "able"}
# event: answer_message
#
#
#
# data: {"text": " segments"}
# event: answer_message
#
#
#
# data: {"text": " and"}
# event: answer_message
#
#
#
# data: {"text": " geographic"}
# event: answer_message
#
#
#
# data: {"text": " management"}
# event: answer_message
#
#
#
# data: {"text": "."}
# event: answer_message
#
#
#
# data: {"text": " If"}
# event: answer_message
#
#
#
# data: {"text": " you"}
# event: answer_message
#
#
#
# data: {"text": " need"}
# event: answer_message
#
#
#
# data: {"text": " further"}
# event: answer_message
#
#
#
# data: {"text": " details"}
# event: answer_message
#
#
#
# data: {"text": " or"}
# event: answer_message
#
#
#
# data: {"text": " specific"}
# event: answer_message
#
#
#
# data: {"text": " financial"}
# event: answer_message
#
#
#
# data: {"text": " metrics"}
# event: answer_message
#
#
#
# data: {"text": ","}
# event: answer_message
#
#
#
# data: {"text": " please"}
# event: answer_message
#
#
#
# data: {"text": " let"}
# event: answer_message
#
#
#
# data: {"text": " me"}
# event: answer_message
#
#
#
# data: {"text": " know"}
# event: answer_message
#
#
#
# data: {"text": "!"}
# event: answer_message
#
#
#
# data: {"text": ""}
# event: answer_message
#
#
#
# [harlus_chat] Streaming source annotations...
# [harlus_chat] Sent 2 source annotations
# data: [{"id": "43929dcd-39fd-45ba-8d5a-a6552dd15a07", "file_path": "/Users/ronald/Library/Application Support/Electron/Harlus/AAPL/20241101_Q4_2024_AAPL_10_K_pdf/content.pdf", "thread_id": "83c24865-1aee-45e1-974e-70295f0b022c", "message_id": "8", "text": "Response source", "highlight_area": {"bounding_boxes": [{"left": 8.20625241063222, "top": 56.32648603933158, "width": 83.58697073800224, "height": 0.9763196641645636, "page": 4}, {"left": 8.20625241063222, "top": 57.46550933765402, "width": 83.58691944795497, "height": 0.9763196641645636, "page": 4}, {"left": 8.20625241063222, "top": 58.68592250941768, "width": 34.64769251206342, "height": 0.9763196641645636, "page": 4}], "jump_to_page_number": 5}, "next_chat_comment_id": ""}, {"id": "5fe6499b-32d7-4300-a6c4-104c54e4105f", "file_path": "/Users/ronald/Library/Application Support/Electron/Harlus/AAPL/20241101_Q4_2024_AAPL_10_K_pdf/content.pdf", "thread_id": "83c24865-1aee-45e1-974e-70295f0b022c", "message_id": "8", "text": "Response source", "highlight_area": {"bounding_boxes": [{"left": 75.24175050879727, "top": 57.46550933765402, "width": 16.551421349789916, "height": 0.9763196641645636, "page": 4}, {"left": 8.20625241063222, "top": 58.68592250941768, "width": 83.58710409212513, "height": 0.9763196641645636, "page": 4}, {"left": 8.20625241063222, "top": 59.82494580774013, "width": 83.5875554445411, "height": 0.9763196641645636, "page": 4}, {"left": 8.20625241063222, "top": 60.964001725801666, "width": 83.58652964359572, "height": 0.9763160397491092, "page": 4}, {"left": 8.20625241063222, "top": 62.18438590224169, "width": 74.93465263302586, "height": 0.9763160397491092, "page": 4}], "jump_to_page_number": 5}, "next_chat_comment_id": "43929dcd-39fd-45ba-8d5a-a6552dd15a07"}]
# event: sources
#
#
#
# data:
# event: complete

# %%
chat.get_thread_ids()
# Out:
# Error retrieving thread IDs: no such column: config
# []
