# %%
import dotenv
dotenv.load_dotenv()

from sec_loader import SecSourceLoader

# %%
loader = SecSourceLoader()
loader.download_files("AAPL")
# Out:
# DATA_DIR /Users/octaveoliviers/projects/harlus/ml/tools/file_loaders/src/data/AAPL/sec
# out /Users/octaveoliviers/projects/harlus/ml/tools/file_loaders/src/data/AAPL/sec
# folder /Users/octaveoliviers/projects/harlus/ml/tools/file_loaders/src/data/AAPL/sec
# DATA_DIR /Users/octaveoliviers/projects/harlus/ml/tools/file_loaders/src/data/AAPL/sec
# out /Users/octaveoliviers/projects/harlus/ml/tools/file_loaders/src/data/AAPL/sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 loader = SecSourceLoader()
# ----> 2 loader.download_files("AAPL")
#
# File ~/projects/harlus/ml/tools/file_loaders/src/harlus_file_loaders/sec_loader.py:110, in download_files(self, ticker)
#     108 filename = row["filename_stem"]
#     109 extension = self._get_extension(source)
# --> 110 target_source = f"{folder}/{filename}.{extension}"
# ...
